# %% [markdown]
# # The evolution of three pointer in NBA

# %%
# %matplotlib inline
import pandas as pd
import ggplot as gg
import matplotlib.pyplot as plt

# %%
def plot_3pt(data_file):
    team_stat=pd.read_csv(data_file)
    g=gg.ggplot(gg.aes(y='3P',x='3PA'),data=team_stat)+gg.geom_point()
    print(g)
    
plot_3pt("./nba_team_data/team_stat_1990.csv")
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# <ggplot: (-9223372036563359733)>

# %%
# team name mapping
long_team_name_map={"New Jersey Nets":"New Jersey/Brooklyn Nets",
 "Brooklyn Nets":"New Jersey/Brooklyn Nets",
 "Charlotte Bobcats":"Charlotte Hornets/Bobcats",
 "Charlotte Hornets": "Charlotte Hornets/Bobcats",
 "Seattle SuperSonics":"Seattle SuperSonics/Oklahoma City Thunder",
 "Oklahoma City Thunder":"Seattle SuperSonics/Oklahoma City Thunder",
 "New Orleans Pelicans":"Oklahoma City Hornets/New Orleans Pelicans/New Orleans Hornets",
 "New Orleans Hornets":"Oklahoma City Hornets/New Orleans Pelicans/New Orleans Hornets",
 "Oklahoma City Hornets":"Oklahoma City Hornets/New Orleans Pelicans/New Orleans Hornets",
 "New Orleans/Oklahoma City Hornets":"Oklahoma City Hornets/New Orleans Pelicans/New Orleans Hornets",
 "Washington Wizards":"Washington Bullets/Wizards",
 "Washington Bullets":"Washington Bullets/Wizards",
 "Memphis Grizzlies":"Vancouver/Memphis Grizzlies",
 "Vancouver Grizzlies":"Vancouver/Memphis Grizzlies"};


short_team_name_map={"New Jersey Nets":"Brooklyn Nets",
 "Charlotte Bobcats":"Charlotte Hornets",
 "Seattle SuperSonics":"Oklahoma City Thunder",
 "New Orleans Hornets":"New Orleans Pelicans",
 "Oklahoma City Hornets":"New Orleans Pelicans",
 "New Orleans/Oklahoma City Hornets":"New Orleans Pelicans",
 "Washington Bullets":"Washington Wizards",
 "Vancouver Grizzlies":"Memphis Grizzlies"};

team_name_map=short_team_name_map

def map_team_name(team_name):
    if team_name in team_name_map.keys():
        return team_name_map[team_name]
    else:
        return team_name

map_team_name("New Jersey Nets")
# Out:
# 'Brooklyn Nets'

# %%
def play_off_team(team_name):
    if team_name[-1]=="*":
        return "play-off team"
    else:
        return "non play-off team"

#assert play_off_team("Atlanta")==False
#assert play_off_team("Atlanta*")==True

def extract_team_name(team_name):
    if team_name[-1]=="*":
        return team_name[:-1]
    else:
        return team_name

assert extract_team_name("Atlanta*")=="Atlanta"
assert extract_team_name("Atlanta")=="Atlanta"

# %%
years=range(1990,2017,1)
df=[]
for y in years:
    idf=pd.read_csv("./nba_team_data/team_stat_%s.csv"%y)
    idf["year"]=y
    # calculate 3-pointer attempts per game
    idf["3PAPG"]=idf["3PA"]/idf["G"]
    # calculate 3-point shots made per game
    idf["3PPG"]=idf["3P"]/idf["G"]
    
    df.append(idf)
    
    idf["play_off"]=[play_off_team(t) for t in idf["Team"]]

    n_team=[extract_team_name(t) for t in idf["Team"]]
    idf["Team"]=n_team
    idf["year_team"]=str(y)+"-"+idf["Team"]
    idf["dummy_col"]=1
    
    n_team=[map_team_name(t) for t in idf["Team"] ]
    idf["Team"]=n_team
    
merged_df=pd.concat(df)

merged_df.to_csv("full_agg_team_stat.csv")
merged_df["play_off"].describe()

abbrev_df=merged_df.loc[:,["year","Team","3PAPG","3PA", "3P", "3P%"]]
abbrev_df.to_csv("agg_team_stat.csv");

# %% [markdown]
# ### Plot three-points per games by year

# %%
g=gg.ggplot(gg.aes(y='3PPG',x='3PAPG',color="year"),data=merged_df)+gg.geom_point()
print(g)
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# 2000  ...   19519  12717  38057  57319  239782  2924.3  411.451220
# 2001  ...   19241  12936  37017  54976  233233  2844.3  411.231707
# 2002  ...   19177  12850  35575  52238  234872  2864.2  442.475610
# 2003  ...   19535  12339  36694  53514  233899  2852.7  440.439024
# 2004  ...   19514  12437  36838  52765  229756  2801.9  447.756098
# 2005  ...   19105  12362  36866  57527  247079  3012.9  488.292683
# 2006  ...   18220  11945  36641  57852  246596  3007.4  495.402439
# 2007  ...   18401  11707  38473  56488  250996  3060.9  525.134146
# 2008  ...   18494  12039  35876  53433  254005  3097.6  561.329268
# 2009  ...   18479  12211  35670  53491  254075  3098.3  561.817073
# 2010  ...   18351  12345  36148  53019  255337  3113.9  562.304878
# 2011  ...   18624  12365  36234  52651  253057  3086.2  558.414634
# 2012  ...   15707  10422  29822  40035  196947  2984.1  569.818182
# 2013  ...   19817  13043  36959  50401  249264  3042.2  618.779283
# 2014  ...   19525  11980  37235  52620  256765  3131.3  667.560976
# 2015  ...   19665  12190  36489  51386  254236  3100.5  694.817073
# 2016  ...    5486   3446  10368  14199   69096  3121.2  736.032529
#
#             3PPG  dummy_col  year
# year
# 1990   61.073171         28  1990
# 1991   63.926829         28  1991
# 1992   70.658537         28  1992
# 1993   84.329268         28  1993
# 1994   92.329268         28  1994
# 1995  153.695122         28  1995
# 1996  176.621951         30  1996
# 1997  181.451220         30  1997
# 1998  131.829268         30  1998
# 1999  133.720000         30  1999
# 2000  145.243902         30  2000
# 2001  145.378049         30  2001
# 2002  156.463415         30  2002
# 2003  153.914634         30  2003
# 2004  155.439024         30  2004
# 2005  173.609756         31  2005
# 2006  177.512195         31  2006
# 2007  188.097561         31  2007
# 2008  203.182927         31  2008
# 2009  206.060976         31  2009
# 2010  199.378049         31  2010
# 2011  200.195122         31  2011
# 2012  198.727273         31  2012
# 2013  221.987805         31  2013
# 2014  240.109756         31  2014
# 2015  243.207317         31  2015
# 2016  256.144857         31  2016
#
# [27 rows x 29 columns]

# %%
g=gg.ggplot(gg.aes(y='3P%',x='year'),data=sum_df)+gg.geom_point()
print(g)
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# <ggplot: (291549346)>

# %% [markdown]
# ### Group (aggregate) the dataframe by year and do averaging

# %%
mean_df=merged_df.groupby(["year"]).mean()
mean_df['year']=mean_df.index
g=gg.ggplot(gg.aes(y='3PAPG',x='year'),data=mean_df)+gg.geom_point()
print(g)
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# <ggplot: (-9223372036563249941)>

# %%
color_code_df=pd.read_csv("NBA_Team_color_codes.csv")

# %%
color_code_df=color_code_df[["Team","color1","color2"]]
new_team_name=[map_team_name(t) for t in color_code_df["Team"]]
color_code_df["Team"]=new_team_name
color_code_df
# Out:
#                       Team   color1   color2
# 0            Atlanta Hawks  #E03A3E  #C3D600
# 1           Boston Celtics  #008348  #000000
# 2            Brooklyn Nets  #000000  #FFFFFF
# 3        Charlotte Hornets  #008CA8  #1D1160
# 4            Chicago Bulls  #CE1141  #000000
# 5      Cleveland Cavaliers  #860038  #FDBB30
# 6         Dallas Mavericks  #007DC5  #C4CED3
# 7           Denver Nuggets  #FFB20F  #4FA8FF
# 8          Detroit Pistons  #ED174C  #006BB6
# 9    Golden State Warriors  #FDB927  #006BB6
# 10         Houston Rockets  #CE1141  #C4CED3
# 11          Indiana Pacers  #00275D  #FFC633
# 12    Los Angeles Clippers  #ED174C  #006BB6
# 13      Los Angeles Lakers  #552582  #FDB927
# 14       Memphis Grizzlies  #23375B  #6189B9
# 15              Miami Heat  #98002E  #F9A01B
# 16         Milwaukee Bucks  #00471B  #EEE1C6
# 17  Minnesota Timberwolves  #005083  #00A94F
# 18    New Orleans Pelicans  #002B5C  #B4975A
# 19         New York Knicks  #006BB6  #F58426
# 20   Oklahoma City Thunder  #007DC3  #F05133
# 21           Orlando Magic  #C4CED3  #007DC5
# 22      Philadelphia 76ers  #ED174C  #006BB6
# 23            Phoenix Suns  #E56020  #1D1160
# 24   Portland Trailblazers  #F0163A  #B6BFBF
# 25        Sacramento Kings  #724C9F  #8E9090
# 26       San Antonio Spurs  #B6BFBF  #000000
# 27         Toronto Raptors  #CE1141  #C4CED3
# 28               Utah Jazz  #00471B  #F9A01B
# 29      Washington Wizards  #002566  #F5002F

# %%
team_code_dict={}
for i in range(color_code_df.shape[0]):
    team_code_dict.update({color_code_df.iloc[i,0]:{"color1":color_code_df.iloc[i,1],"color2":color_code_df.iloc[i,2]}})

import json
json.dumps(team_code_dict)
# Out:
# '{"Phoenix Suns": {"color1": "#E56020", "color2": "#1D1160"}, "Miami Heat": {"color1": "#98002E", "color2": "#F9A01B"}, "New Orleans Pelicans": {"color1": "#002B5C", "color2": "#B4975A"}, "Washington Wizards": {"color1": "#002566", "color2": "#F5002F"}, "Orlando Magic": {"color1": "#C4CED3", "color2": "#007DC5"}, "Charlotte Hornets": {"color1": "#008CA8", "color2": "#1D1160"}, "Minnesota Timberwolves": {"color1": "#005083", "color2": "#00A94F"}, "Golden State Warriors": {"color1": "#FDB927", "color2": "#006BB6"}, "Memphis Grizzlies": {"color1": "#23375B", "color2": "#6189B9"}, "Cleveland Cavaliers": {"color1": "#860038", "color2": "#FDBB30"}, "Detroit Pistons": {"color1": "#ED174C", "color2": "#006BB6"}, "Brooklyn Nets": {"color1": "#000000", "color2": "#FFFFFF"}, "Philadelphia 76ers": {"color1": "#ED174C", "color2": "#006BB6"}, "Toronto Raptors": {"color1": "#CE1141", "color2": "#C4CED3"}, "New York Knicks": {"color1": "#006BB6", "color2": "#F58426"}, "Denver Nuggets": {"color1": "#FFB20F", "color2": "#4FA8FF"}, "Utah Jazz": {"color1": "#00471B", "color2": "#F9A01B"}, "Portland Trailblazers": {"color1": "#F0163A", "color2": "#B6BFBF"}, "Atlanta Hawks": {"color1": "#E03A3E", "color2": "#C3D600"}, "Los Angeles Clippers": {"color1": "#ED174C", "color2": "#006BB6"}, "Chicago Bulls": {"color1": "#CE1141", "color2": "#000000"}, "San Antonio Spurs": {"color1": "#B6BFBF", "color2": "#000000"}, "Dallas Mavericks": {"color1": "#007DC5", "color2": "#C4CED3"}, "Indiana Pacers": {"color1": "#00275D", "color2": "#FFC633"}, "Houston Rockets": {"color1": "#CE1141", "color2": "#C4CED3"}, "Boston Celtics": {"color1": "#008348", "color2": "#000000"}, "Sacramento Kings": {"color1": "#724C9F", "color2": "#8E9090"}, "Oklahoma City Thunder": {"color1": "#007DC3", "color2": "#F05133"}, "Milwaukee Bucks": {"color1": "#00471B", "color2": "#EEE1C6"}, "Los Angeles Lakers": {"color1": "#552582", "color2": "#FDB927"}}'
